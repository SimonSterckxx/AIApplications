# %%
# !nvdia-smi
# Out:
# /bin/bash: line 1: nvdia-smi: command not found

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.7/882.7 kB 11.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import Image, display
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics 8.3.11 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 36.6/107.7 GB disk)
#
# OS                  Linux-6.1.85+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# Disk                36.6/107.7 GB
# CPU                 Intel Xeon 2.20GHz
# CPU count           2
# GPU                 None
# GPU count           None
# CUDA                None
#
# numpy               ✅ 1.26.4>=1.23.0
# matplotlib          ✅ 3.7.1>=3.3.0
# opencv-python       ✅ 4.10.0.84>=4.6.0
# pillow              ✅ 10.4.0>=7.1.2
# pyyaml              ✅ 6.0.2>=5.3.1
# requests            ✅ 2.32.3>=2.23.0
# scipy               ✅ 1.13.1>=1.4.1
# torch               ✅ 2.4.1+cu121>=1.8.0
# torchvision         ✅ 0.19.1+cu121>=0.9.0
# tqdm                ✅ 4.66.5>=4.64.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# pandas              ✅ 2.2.2>=1.1.4
# ...

# %%
# %pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="FkKYFeQayaKInNYYHdDG")
project = rf.workspace("aiapplication-tyfsu").project("peopletracking-iqmbi")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.3.11, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to PeopleTracking-2 in yolov8:: 100%|██████████| 12722/12722 [00:03<00:00, 4078.27it/s]

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=PeopleTracking-2/data.yaml epochs=20 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 184MB/s]
# Ultralytics 8.3.11 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
Image(filename=f'/content/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-bed2f95afbc3> in <cell line: 1>()
# ----> 1 Image(filename=f'/content/runs/detect/train/confusion_matrix.png', width=600)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
Image(filename=f'/content/runs/detect/train2/results.png', width=600)

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt source=/content/PeopleTracking-1/test/images
# Out:
# Ultralytics 8.3.11 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 236 layers, 23,203,411 parameters, 0 gradients, 67.4 GFLOPs
#
# image 1/73 /content/PeopleTracking-1/test/images/00000022_png_jpg.rf.cb9a11d8a4a82962fa6dd5a1afa45879.jpg: 640x640 2 persons, 34.4ms
# image 2/73 /content/PeopleTracking-1/test/images/00000083_png_jpg.rf.1615f710e90fc79b5876981bd57a4786.jpg: 640x640 2 persons, 34.4ms
# image 3/73 /content/PeopleTracking-1/test/images/00000091_png_jpg.rf.0877763b0c4fd633e3449ec71ff749f7.jpg: 640x640 2 persons, 34.3ms
# image 4/73 /content/PeopleTracking-1/test/images/00000289_png_jpg.rf.9a88f1cd1608af991220bfd8fb649edf.jpg: 640x640 2 persons, 34.3ms
# image 5/73 /content/PeopleTracking-1/test/images/00000295_png_jpg.rf.6bc2e23c74c7764903bc1e3d37ed7b1f.jpg: 640x640 2 persons, 34.3ms
# image 6/73 /content/PeopleTracking-1/test/images/00000328_png_jpg.rf.c69638ce54f88240eba8eda284fc617d.jpg: 640x640 2 persons, 34.3ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt source=/content/PeopleTracking-1/test/images
# Out:
# Ultralytics 8.3.11 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 236 layers, 23,203,411 parameters, 0 gradients, 67.4 GFLOPs
#
# image 1/73 /content/PeopleTracking-1/test/images/00000022_png_jpg.rf.cb9a11d8a4a82962fa6dd5a1afa45879.jpg: 640x640 2 persons, 34.4ms
# image 2/73 /content/PeopleTracking-1/test/images/00000083_png_jpg.rf.1615f710e90fc79b5876981bd57a4786.jpg: 640x640 2 persons, 34.4ms
# image 3/73 /content/PeopleTracking-1/test/images/00000091_png_jpg.rf.0877763b0c4fd633e3449ec71ff749f7.jpg: 640x640 2 persons, 34.4ms
# image 4/73 /content/PeopleTracking-1/test/images/00000289_png_jpg.rf.9a88f1cd1608af991220bfd8fb649edf.jpg: 640x640 2 persons, 34.3ms
# image 5/73 /content/PeopleTracking-1/test/images/00000295_png_jpg.rf.6bc2e23c74c7764903bc1e3d37ed7b1f.jpg: 640x640 2 persons, 29.8ms
# image 6/73 /content/PeopleTracking-1/test/images/00000328_png_jpg.rf.c69638ce54f88240eba8eda284fc617d.jpg: 640x640 2 persons, 24.3ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/runs/detect/predict2/*.jpg'):
  display(Image(filename=image_path, height=600))
  print("\n")
# Out:
# Output hidden; open in https://colab.research.google.com to view.
